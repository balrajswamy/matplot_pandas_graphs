# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
cars = {"Bmw": 1000, "Audi": 3000, "Benz":4000}

fig, ax = plt.subplots()
ax.set(title="Cars Price Data", xlabel="Cars", ylabel="Price")
ax.bar(cars.keys(),cars.values())
plt.show()
